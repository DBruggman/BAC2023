# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SBAnational.csv')
# Out:
# /var/folders/nt/9wb2rhv97959gh0yy716ljlw0000gn/T/ipykernel_1881/2640212651.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('SBAnational.csv')

# %%
df.sample(10)
# Out:
#         LoanNr_ChkDgt                            Name       City State    Zip  \
# 664265     6728724010        G & K MANUFACTURING INC.  SUNNYVALE    CA  94089
# 803555     8610374005                         L A TAN    WHEATON    IL  60187
# 826922     8872424007  THE WILLIAMS BUSINESS GROUP LL     LAUREL    MD  20707
# 873769     9440364003     PANEK'S GOLF CAR SERVICE CO    WINDSOR    NJ   8561
# 248976     2752844002                 FLASHBACK VIDEO    BOULDER    CO  80304
# 750642     7835214010                    TOY TOWN INC   FOX LAKE    IL  60020
# 109342     1800925010                    Kenneth Cahn    HOUSTON    TX  77020
# 251465     2768684007        LINDER'S GREENHOUSES INC  LAKE ELMO    MN  55042
# 33110      1250285002  JONATHAN P EVANS DBA IBUYUSEDL   ANDERSON    SC  29621
# 455127     4408954000                 MAGNOLIA TEXACO   MAGNOLIA    TX  77355
#
#                                   Bank BankState   NAICS ApprovalDate  \
# 664265        MORTGAGE CAP. DEVEL CORP        CA  332212    25-Sep-03
# 803555  PNC BANK, NATIONAL ASSOCIATION        DE  812112    14-Feb-05
# 826922                       BBCN BANK        CA  453998    19-May-05
# 873769       FULTON BANK OF NEW JERSEY        NJ  811118    14-Dec-05
# 248976               PUEBLO BK & TR CO        CO  512110     1-Feb-99
# 750642  U.S. BANK NATIONAL ASSOCIATION        OH  451120    22-Sep-04
# 109342  JPMORGAN CHASE BANK NATL ASSOC        IL  442299     4-May-06
# 251465   TWIN CITIES-METRO CERT. DEVEL        MN       0     8-Feb-99
# 33110       BANK OF AMERICA NATL ASSOC        NC  453998    30-Mar-05
# 455127                    COMPASS BANK        AL  447110    30-Mar-01
#
#        ApprovalFY  ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  \
# 664265       2003  ...          N       N         NaN         17-Dec-03
# 803555       2005  ...          0       N         NaN         30-Sep-05
# 826922       2005  ...          0       N         NaN         31-May-05
# 873769       2006  ...          Y       N         NaN         31-Jan-06
# 248976       1999  ...          N       N         NaN         30-Apr-99
# 750642       2004  ...          Y       N    7-Apr-06         30-Sep-04
# 109342       2006  ...          Y       N   22-Oct-12         31-May-06
# 251465       1999  ...          0       N         NaN         14-Apr-99
# 33110        2005  ...          Y       N         NaN         30-Apr-08
# 455127       2001  ...          0       N         NaN         30-Apr-01
#
#         DisbursementGross  BalanceGross  MIS_Status ChgOffPrinGr  \
# 664265       $825,000.00         $0.00        P I F       $0.00
# 803555       $240,000.00         $0.00        P I F       $0.00
# 826922        $11,000.00         $0.00        P I F       $0.00
# 873769       $168,998.00         $0.00        P I F       $0.00
# 248976       $187,000.00         $0.00        P I F       $0.00
# 750642        $25,468.00         $0.00       CHGOFF  $21,055.00
# 109342       $178,054.00         $0.00       CHGOFF  $36,053.00
# 251465       $284,000.00         $0.00        P I F       $0.00
# 33110          $5,000.00         $0.00        P I F       $0.00
# 455127       $950,000.00         $0.00        P I F       $0.00
#
#               GrAppv      SBA_Appv
# 664265  $825,000.00   $825,000.00
# 803555  $240,000.00   $180,000.00
# 826922   $11,000.00     $9,350.00
# 873769  $100,000.00    $50,000.00
# 248976  $187,000.00   $140,250.00
# 750642   $25,000.00    $12,500.00
# 109342   $50,000.00    $25,000.00
# 251465  $284,000.00   $284,000.00
# 33110     $5,000.00     $2,500.00
# 455127  $950,000.00   $712,500.00
#
# [10 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   LoanNr_ChkDgt      899164 non-null  int64
#  1   Name               899150 non-null  object
#  2   City               899134 non-null  object
#  3   State              899150 non-null  object
#  4   Zip                899164 non-null  int64
#  5   Bank               897605 non-null  object
#  6   BankState          897598 non-null  object
#  7   NAICS              899164 non-null  int64
#  8   ApprovalDate       899164 non-null  object
#  9   ApprovalFY         899164 non-null  object
#  10  Term               899164 non-null  int64
#  11  NoEmp              899164 non-null  int64
#  12  NewExist           899028 non-null  float64
#  13  CreateJob          899164 non-null  int64
#  14  RetainedJob        899164 non-null  int64
#  15  FranchiseCode      899164 non-null  int64
#  16  UrbanRural         899164 non-null  int64
#  17  RevLineCr          894636 non-null  object
#  18  LowDoc             896582 non-null  object
#  19  ChgOffDate         162699 non-null  object
#  20  DisbursementDate   896796 non-null  object
#  21  DisbursementGross  899164 non-null  object
#  22  BalanceGross       899164 non-null  object
#  23  MIS_Status         897167 non-null  object
#  24  ChgOffPrinGr       899164 non-null  object
#  25  GrAppv             899164 non-null  object
#  26  SBA_Appv           899164 non-null  object
# dtypes: float64(1), int64(9), object(17)
# memory usage: 185.2+ MB

# %%
df[df['Bank'].isnull()]['LoanNr_ChkDgt'].count()
# Out:
# 1559

# %%
DEFAULT = 'CHGOFF'
PIF = 'P I F'

samples = df.shape[0]

MIS_counts = df['MIS_Status'].value_counts()
pif_count = MIS_counts[PIF]
chgoff_count = MIS_counts[DEFAULT]
unknown = samples - pif_count - chgoff_count

print(f"{samples} total samples, with {pif_count} paid in full, {chgoff_count} defaulted and {unknown} null")
# Out:
# 899164 total samples, with 739609 paid in full, 157558 defaulted and 1997 null

# %%
lates = df[(df['MIS_Status'] == PIF) & (df['ChgOffDate'].notnull())]
print(f"{len(lates)} late payments found")
lates.head()
# Out:
# 4927 late payments found
#      LoanNr_ChkDgt                            Name                       City  \
# 558     1004176005                GREENLIFE MOBILE                   SAN JOSE
# 850     1005925000  GILLIAN'S DELICATESSEN & CATER                FLORAL PARK
# 853     1005936010  TRICAS MANAGEMENT SERVICES LLC                     DALLAS
# 861     1005986003  CAPITAL EXPLOSION GRAPHIC DESI  UPPER MARLBORO (MARLBORO)
# 866     1006016007   C-BARB AND CONLEY PROMOTIONAL                    HOUSTON
#
#     State    Zip                            Bank BankState   NAICS  \
# 558    CA  95132                       BBCN BANK        CA  561730
# 850    NY  11001  JPMORGAN CHASE BANK NATL ASSOC        IL  722320
# 853    TX  75218     WELLS FARGO BANK NATL ASSOC        SD  621511
# 861    MD  20774                       BBCN BANK        CA  541430
# 866    TX  77057                       BBCN BANK        CA  421450
#
#     ApprovalDate ApprovalFY  ...  RevLineCr  LowDoc  ChgOffDate  \
# 558     7-Feb-06       2006  ...          0       N   19-Oct-09
# 850    26-Mar-03       2003  ...          N       N   29-Mar-06
# 853     8-Feb-06       2006  ...          Y       N    2-Feb-09
# 861     8-Feb-06       2006  ...          0       N   14-Aug-12
# 866     8-Feb-06       2006  ...          0       N    1-Jun-09
#
#      DisbursementDate  DisbursementGross  BalanceGross  MIS_Status  \
# 558         28-Feb-06         $5,000.00         $0.00        P I F
# 850         31-Mar-03        $15,000.00         $0.00        P I F
# 853         31-Mar-06       $165,553.00         $0.00        P I F
# 861         28-Feb-06        $10,000.00         $0.00        P I F
# 866         28-Feb-06         $5,000.00         $0.00        P I F
#
#     ChgOffPrinGr        GrAppv     SBA_Appv
# 558   $3,330.00     $5,000.00    $4,250.00
# 850  $10,270.00    $15,000.00    $7,500.00
# 853  $97,486.00   $100,000.00   $50,000.00
# 861   $2,310.00    $10,000.00    $8,500.00
# 866   $3,783.00     $5,000.00    $4,250.00
#
# [5 rows x 27 columns]

# %%
most_common = df['BalanceGross'].mode()[0]

wierds = df[(df['BalanceGross'] != most_common)]
wierds
# Out:
#         LoanNr_ChkDgt                            Name          City State  \
# 18555      1135885010  Francisco Ruiz dba Susquehanna     ALLENTOWN    PA
# 28198      1211926008  GULF COAST COIL TUBING & NITRO         SCOTT    LA
# 253953     2784255003            NAR Enterprises, LLC     LAFAYETTE    CO
# 339776     3369895004      Local Ocean Seafoods, Inc.       Newport    OR
# 382117     3686985000                    Planet Beach     Blue bell    PA
# 389415     3751605010             Bella's Resale Shop       Chicago    IL
# 518257     5011163010          OLSON, CLYDE & DARLENE      MARKESAN    WI
# 534838     5225724003          GRANITE MFG STONEWORKS      HOLBROOK    NY
# 759993     7960044006  BITS & CHIPS MACHINING CO. INC    MIDDLETOWN    OH
# 766068     8047854007          DAYS INN OF CLEARFIELD  WILKES-BARRE    PA
# 770280     8119914001            PETS IN THE CITY LLC     ST. LOUIS    MO
# 820834     8807974001              INDIGO HAIR STUDIO      MUSKEGON    MI
# 852542     9141504008               JOHNSON-HOBBY INC        GIRARD    OH
# 870511     9397624002           GYMBOREE PLAY & MUSIC    SHREVEPORT    LA
#
#           Zip                            Bank BankState   NAICS ApprovalDate  \
# 18555   18103      BANK OF AMERICA NATL ASSOC        NC  811111    21-Dec-04
# 28198   70583                       HOME BANK        LA  213112     1-Mar-06
# 253953  80026  JPMORGAN CHASE BANK NATL ASSOC        IL  722211    30-Oct-07
# 339776  97365                 WEST COAST BANK        OR  722110     7-Apr-09
# 382117  19422               PENN LIBERTY BANK        PA  812199     9-Oct-09
# 389415  60617                    CENTIER BANK        IN  453310    16-Nov-09
# 518257  53946        BMO HARRIS BK NATL ASSOC        IL  713950     8-Sep-92
# 534838  11741           READYCAP LENDING, LLC        CA  327991    20-Feb-02
# 759993  45044              SPRING VALLEY BANK        OH  333911    19-Oct-04
# 766068  18702                  CUSTOMERS BANK        NJ  721110     3-Nov-04
# 770280  63118  U.S. BANK NATIONAL ASSOCIATION        OH  453910    16-Nov-04
# 820834  49441                FIFTH THIRD BANK        OH  812112    21-Apr-05
# 852542  44420     BANCO POPULAR NORTH AMERICA        NY  561730    30-Sep-05
# 870511  71106           AMER NATL BK OF TEXAS        TX  624410     8-Dec-05
#
#        ApprovalFY  ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  \
# 18555        2005  ...          T       N         NaN         31-Jan-05
# 28198        2006  ...          N       N         NaN         30-Jun-06
# 253953       2008  ...          Y       N         NaN         30-Nov-07
# 339776       2009  ...          Y       N         NaN         30-Apr-09
# 382117       2010  ...          Y       N         NaN          1-May-10
# 389415       2010  ...          N       N         NaN          1-Jan-10
# 518257       1992  ...          N       N         NaN         31-Oct-92
# 534838       2002  ...          0       N         NaN         30-Apr-02
# 759993       2005  ...          N       N         NaN         30-Sep-05
# 766068       2005  ...          0       N         NaN         31-Jan-05
# 770280       2005  ...          T       N         NaN         30-Nov-04
# 820834       2005  ...          0       Y         NaN         31-May-05
# 852542       2005  ...          0       N         NaN         30-Nov-05
# 870511       2006  ...          0       N         NaN         31-Jan-06
#
#         DisbursementGross  BalanceGross  MIS_Status ChgOffPrinGr  \
# 18555         $39,875.00    $12,750.00        P I F       $0.00
# 28198      $1,080,000.00   $827,875.00        P I F       $0.00
# 253953        $87,491.00    $25,000.00        P I F       $0.00
# 339776       $166,826.00    $37,100.00        P I F       $0.00
# 382117        $75,000.00    $43,127.00        P I F       $0.00
# 389415        $90,000.00    $84,617.00        P I F       $0.00
# 518257       $245,000.00     $1,760.00        P I F       $0.00
# 534838       $825,000.00   $115,820.00        P I F       $0.00
# 759993     $1,070,000.00   $996,262.00        P I F       $0.00
# 766068     $1,330,000.00   $395,476.00        P I F       $0.00
# 770280        $41,509.00    $41,509.00        P I F       $0.00
# 820834        $10,000.00       $600.00        P I F       $0.00
# 852542     $1,038,000.00     $9,111.00        P I F       $0.00
# 870511       $150,000.00    $96,908.00        P I F       $0.00
#
#                 GrAppv      SBA_Appv
# 18555      $13,000.00     $6,500.00
# 28198   $1,080,000.00   $810,000.00
# 253953     $25,000.00    $12,500.00
# 339776    $100,000.00    $50,000.00
# 382117     $75,000.00    $37,500.00
# 389415    $120,000.00    $60,000.00
# 518257    $245,000.00   $183,750.00
# 534838    $825,000.00   $618,750.00
# 759993  $1,070,000.00   $802,500.00
# 766068  $1,330,000.00   $997,500.00
# 770280     $47,000.00    $39,950.00
# 820834     $10,000.00     $8,500.00
# 852542  $1,038,000.00   $778,500.00
# 870511    $150,000.00    $75,000.00
#
# [14 rows x 27 columns]

# %%
features_keep = ['Term', 'NewExist', 'NoEmp', 'UrbanRural', 'RevLineCr']

df[features_keep].sample(10)
# Out:
#         Term  NewExist  NoEmp  UrbanRural RevLineCr
# 870360   240       1.0      1           1         0
# 163896    84       1.0      3           0         Y
# 185902    21       2.0      1           0         N
# 735693    84       1.0      2           1         Y
# 712861    84       1.0      7           1         0
# 436125   168       1.0     49           0         N
# 634176    27       2.0      1           2         Y
# 702546    63       1.0      5           2         0
# 268381    84       1.0      4           1         0
# 125434    12       1.0     65           0         Y

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['NoEmp'], bins='auto', alpha=0.7, color='skyblue', edgecolor='black', log=True)

# Calculate quartiles
q1 = df['NoEmp'].quantile(0.25)
q2 = df['NoEmp'].quantile(0.5)
q3 = df['NoEmp'].quantile(0.75)

# Overlay quartile lines
plt.axvline(q1, color='red', linestyle='--', label='Q1')
plt.axvline(q2, color='green', linestyle='--', label='Q2 (Median)')
plt.axvline(q3, color='orange', linestyle='--', label='Q3')

plt.title('Histogram with Logarithmic Bins and Quartiles')
plt.xlabel('Values')
plt.ylabel('Frequency (log scale)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Dividing data into three bins with equal samples
df['Bins'] = pd.qcut(df['NoEmp'], q=3, labels=['Bin 1', 'Bin 2', 'Bin 3'])

# Plotting a bar chart to represent the bins
bin_counts = df['Bins'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.bar(bin_counts.index, bin_counts.values, color='skyblue', edgecolor='black')

plt.title('Distribution into Three Bins with Equal Samples')
plt.xlabel('Bins')
plt.ylabel('Number of Samples')
plt.grid(axis='y')
plt.show()

# %%
df['FranchiseCode'].value_counts().head(20)
# Out:
# FranchiseCode
# 1        638554
# 0        208835
# 78760      3373
# 68020      1921
# 50564      1034
# 21780      1003
# 25650       715
# 79140       659
# 22470       615
# 17998       606
# 52000       576
# 24850       537
# 10528       435
# 67750       420
# 9050        378
# 21420       370
# 10465       365
# 72590       347
# 52875       333
# 38605       325
# Name: count, dtype: int64

# %%
#df[(df['FranchiseCode'] != 1) & (df['FranchiseCode'] != 0)]
df[df['FranchiseCode'] == 79140]
# Out:
#         LoanNr_ChkDgt                            Name           City State  \
# 1227       1008446000                         SUPER 8       PHILLIPS    WI
# 2583       1017194007                SUPER 8 - WARREN         WARREN    IN
# 3964       1026874001              RANDAL MATAJI, LLC       FRANKLIN    TN
# 4621       1031776003        MOORHEAD MOTEL GROUP LLC       MOORHEAD    MN
# 7178       1048874002         SUPER 8 - SPRING VALLEY  SPRING VALLEY    CA
# ...               ...                             ...            ...   ...
# 897094     9949973005  SUPER 8 MOTEL OF GRANITE FALLS  GRANITE FALLS    MN
# 897445     9958043010  SUPER 8 MOTEL PROTHRO JUNCTION    LITTLE ROCK    AR
# 897973     9970623010                   SUPER 8 MOTEL        WALDORF    MD
# 898324     9977603007                         SUPER 8         DILLON    SC
# 898743     9986993010        SUPER 8 MOTEL OF NEEDLES        NEEDLES    CA
#
#           Zip                            Bank BankState   NAICS ApprovalDate  \
# 1227    54555  WISCONSIN BUS. DEVEL FINAN COR        WI  721110     8-Feb-06
# 2583    46792   INDIANA STATEWIDE CERT. DEVEL        IN       0     7-Mar-97
# 3964    37067                 AURORA BANK FSB        CO       0    11-Mar-97
# 4621    56560           DAKOTA CERT. DEVEL CO        ND  721110    13-Feb-06
# 7178    91977                   COMERICA BANK        TX       0    19-Mar-97
# ...       ...                             ...       ...     ...          ...
# 897094  56241       MINNESOTA BUS. FINAN CORP        MN       0     7-Feb-97
# 897445  72117         FIRST WESTERN SBLC, INC        TX       0    11-Feb-97
# 897973  20601       BUSINESS LOAN CENTER, LLC        SC       0    18-Feb-97
# 898324  29536     WELLS FARGO BANK NATL ASSOC        SD       0    20-Feb-97
# 898743  92363     WELLS FARGO BANK NATL ASSOC        SD       0    25-Feb-97
#
#        ApprovalFY  ...  LowDoc  ChgOffDate  DisbursementDate  \
# 1227         2006  ...       N         NaN         14-Jun-06
# 2583         1997  ...       N         NaN         13-Sep-00
# 3964         1997  ...       N         NaN         31-May-99
# 4621         2006  ...       N         NaN         15-Nov-06
# 7178         1997  ...       N         NaN         30-Apr-97
# ...           ...  ...     ...         ...               ...
# 897094       1997  ...       N         NaN         11-Mar-98
# 897445       1997  ...       N         NaN         30-Apr-97
# 897973       1997  ...       N   12-Dec-00         31-Aug-97
# 898324       1997  ...       N         NaN         30-Apr-97
# 898743       1997  ...       N         NaN         31-Jul-97
#
#         DisbursementGross  BalanceGross  MIS_Status  ChgOffPrinGr  \
# 1227         $204,000.00         $0.00        P I F        $0.00
# 2583         $611,000.00         $0.00        P I F        $0.00
# 3964       $1,500,000.00         $0.00        P I F        $0.00
# 4621         $413,000.00         $0.00        P I F        $0.00
# 7178         $935,000.00         $0.00        P I F        $0.00
# ...                   ...           ...         ...           ...
# 897094       $373,000.00         $0.00        P I F        $0.00
# 897445     $1,295,000.00         $0.00        P I F        $0.00
# 897973     $1,000,000.00         $0.00       CHGOFF  $401,468.00
# 898324     $1,183,000.00         $0.00        P I F        $0.00
# 898743        $25,000.00         $0.00        P I F        $0.00
#
#                 GrAppv      SBA_Appv   Bins
# 1227      $204,000.00   $204,000.00   Bin 2
# 2583      $611,000.00   $611,000.00   Bin 2
# 3964    $1,500,000.00   $750,000.00   Bin 3
# 4621      $413,000.00   $413,000.00   Bin 3
# 7178      $935,000.00   $701,250.00   Bin 3
# ...                ...           ...    ...
# 897094    $373,000.00   $373,000.00   Bin 3
# 897445  $1,295,000.00   $749,805.00   Bin 3
# 897973  $1,000,000.00   $750,000.00   Bin 3
# 898324  $1,277,000.00   $749,998.00   Bin 3
# 898743     $25,000.00    $12,500.00   Bin 2
#
# [659 rows x 28 columns]

# %%
#df['UrbanRural'].value_counts()
#df[(df['RevLineCr'])]
df['RevLineCr'].value_counts()
#df['LowDoc'].value_counts()
#df['NewExist'].value_counts()
# Out:
# RevLineCr
# N    420288
# 0    257602
# Y    201397
# T     15284
# 1        23
# R        14
# `        11
# 2         6
# C         2
# 3         1
# ,         1
# 7         1
# A         1
# 5         1
# .         1
# 4         1
# -         1
# Q         1
# Name: count, dtype: int64

# %%
#convert dollar values to float value
def dollar_to_float(dollar_string: str):
    return float(dollar_string.replace('$','').replace(',',''))

val = dollar_to_float('$1,560,275.23')
print(f"the value is:{val} and its type is: {type(val)}")
# Out:
# the value is:1560275.23 and its type is: <class 'float'>

# %%
df['GrAppvFloat'] = df['GrAppv'].apply(dollar_to_float)
df['GrSBA_Appv'] = df['SBA_Appv'].apply(dollar_to_float)
df.head()
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
#    ...  DisbursementDate  DisbursementGross  BalanceGross  MIS_Status  \
# 0  ...         28-Feb-99        $60,000.00         $0.00        P I F
# 1  ...         31-May-97        $40,000.00         $0.00        P I F
# 2  ...         31-Dec-97       $287,000.00         $0.00        P I F
# 3  ...         30-Jun-97        $35,000.00         $0.00        P I F
# 4  ...         14-May-97       $229,000.00         $0.00        P I F
#
#    ChgOffPrinGr        GrAppv      SBA_Appv   Bins GrAppvFloat GrSBA_Appv
# 0        $0.00    $60,000.00    $48,000.00   Bin 2     60000.0    48000.0
# 1        $0.00    $40,000.00    $32,000.00   Bin 1     40000.0    32000.0
# 2        $0.00   $287,000.00   $215,250.00   Bin 2    287000.0   215250.0
# 3        $0.00    $35,000.00    $28,000.00   Bin 1     35000.0    28000.0
# 4        $0.00   $229,000.00   $229,000.00   Bin 3    229000.0   229000.0
#
# [5 rows x 30 columns]

# %%
#df['GrSBA_Appv'].describe()
df['GrAppvFloat'].describe()
# Out:
# count    8.991640e+05
# mean     1.926870e+05
# std      2.832634e+05
# min      2.000000e+02
# 25%      3.500000e+04
# 50%      9.000000e+04
# 75%      2.250000e+05
# max      5.472000e+06
# Name: GrAppvFloat, dtype: float64

# %%
df['SBARatio'] = df['GrSBA_Appv'] / df['GrAppvFloat']
df['SBARatio'].value_counts().tail(20)
# Out:
# SBARatio
# 0.800007    1
# 0.827201    1
# 0.883009    1
# 0.597108    1
# 0.566080    1
# 0.799991    1
# 0.503179    1
# 0.648649    1
# 0.456760    1
# 0.899985    1
# 0.850003    1
# 0.850000    1
# 0.854253    1
# 0.850000    1
# 0.849999    1
# 0.513340    1
# 0.799996    1
# 0.750001    1
# 0.823240    1
# 0.698900    1
# Name: count, dtype: int64

# %%
df[(df['SBARatio'] > .75) & (df['SBARatio'] <= .7501)]
# Out:
#         LoanNr_ChkDgt                            Name                  City  \
# 1427       1009614002               CAL-SUNGOLD, INC.               THERMAL
# 2026       1013814006      NORTHEAST PAINT/BODY, INC.  NORTH RICHLAND HILLS
# 2712       1017974005   FUTURE KIDS CHRISTIAN ACADEMY               JACKSON
# 2903       1019164002  D.S. ELECTRICAL CONTRACTORS IN       MENOMONEE FALLS
# 3226       1021334004             ERNIE'S OASIS, INC.             PATASKALA
# ...               ...                             ...                   ...
# 898707     9986313005    LUCAR TRUCKING COMPANY, INC.           CHULA VISTA
# 898770     9987513008                  THE EMPIRE CO.                UPLAND
# 898957     9991513000           MICROTEK LABORATORIES         ANAHEIM HILLS
# 898972     9991713001        KARYS FOOD CENTERS, INC.                 BEACH
# 898997     9992723006      WEST TEXAS LEE COMPANY INC                IDALOU
#
#        State    Zip               Bank BankState   NAICS ApprovalDate  \
# 1427      CA  92274       COMPASS BANK        CA       0     4-Mar-97
# 2026      TX  76180         FROST BANK        TX  811121     6-Mar-97
# 2712      MS  39213  BANCORPSOUTH BANK        MS  624410     7-Mar-97
# 2903      WI  53051          PARK BANK        WI  235310     7-Mar-97
# 3226      OH  43062     HEARTLAND BANK        OH       0    10-Mar-97
# ...      ...    ...                ...       ...     ...          ...
# 898707    CA  91912         FIRST BANK        CA       0    25-Feb-97
# 898770    CA  91785         FIRST BANK        MO       0    25-Feb-97
# 898957    CA  92807         FIRST BANK        MO       0    26-Feb-97
# 898972    ND  58621   BANK OF THE WEST        ND       0    26-Feb-97
# 898997    TX  79329         VISTA BANK        TX       0    27-Feb-97
#
#        ApprovalFY  ...  DisbursementGross  BalanceGross  MIS_Status  \
# 1427         1997  ...       $487,233.00         $0.00        P I F
# 2026         1997  ...        $65,000.00         $0.00        P I F
# 2712         1997  ...       $159,000.00         $0.00        P I F
# 2903         1997  ...       $150,450.00         $0.00        P I F
# 3226         1997  ...       $676,778.00         $0.00        P I F
# ...           ...  ...                ...           ...         ...
# 898707       1997  ...       $146,250.00         $0.00        P I F
# 898770       1997  ...       $408,473.00         $0.00        P I F
# 898957       1997  ...       $210,205.00         $0.00        P I F
# 898972       1997  ...       $123,770.00         $0.00        P I F
# 898997       1997  ...        $62,425.00         $0.00        P I F
#
#         ChgOffPrinGr        GrAppv      SBA_Appv   Bins GrAppvFloat  \
# 1427          $0.00   $487,233.00   $365,425.00   Bin 3    487233.0
# 2026          $0.00    $66,902.00    $50,177.00   Bin 3     66902.0
# 2712          $0.00   $215,090.00   $161,318.00   Bin 2    215090.0
# 2903          $0.00   $150,450.00   $112,838.00   Bin 3    150450.0
# 3226          $0.00   $676,778.00   $507,584.00   Bin 3    676778.0
# ...              ...           ...           ...    ...         ...
# 898707        $0.00   $146,250.00   $109,688.00   Bin 3    146250.0
# 898770        $0.00   $408,473.00   $306,355.00   Bin 3    408473.0
# 898957        $0.00   $210,205.00   $157,654.00   Bin 3    210205.0
# 898972        $0.00   $163,770.00   $122,828.00   Bin 3    163770.0
# 898997        $0.00    $62,425.00    $46,819.00   Bin 3     62425.0
#
#        GrSBA_Appv  SBARatio
# 1427     365425.0  0.750001
# 2026      50177.0  0.750007
# 2712     161318.0  0.750002
# 2903     112838.0  0.750003
# 3226     507584.0  0.750001
# ...           ...       ...
# 898707   109688.0  0.750003
# 898770   306355.0  0.750001
# 898957   157654.0  0.750001
# 898972   122828.0  0.750003
# 898997    46819.0  0.750004
#
# [1735 rows x 31 columns]

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['SBARatio'], bins='auto', alpha=0.7, color='skyblue', edgecolor='black', log=False)

# Calculate quartiles
q1 = df['SBARatio'].quantile(0.25)
q2 = df['SBARatio'].quantile(0.5)
q3 = df['SBARatio'].quantile(0.75)

# Overlay quartile lines
plt.axvline(q1, color='red', linestyle='--', label='Q1')
plt.axvline(q2, color='green', linestyle='--', label='Q2 (Median)')
plt.axvline(q3, color='orange', linestyle='--', label='Q3')

plt.title('Histogram with Logarithmic Bins and Quartiles')
plt.xlabel('Values')
plt.ylabel('Frequency (log scale)')
plt.legend()
plt.grid(True)
plt.show()
